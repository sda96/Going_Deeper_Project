# %%
import numpy as np
import seaborn as sns; 
import matplotlib.pyplot as plt

from konlpy.tag import Mecab
from packages.utils import text_preprocessing
from gensim.models import Word2Vec

import re
import time

# %% [markdown]
# ## STEP 1. 형태소 분석기 이용해서 명사 추출

# %%
mecab = Mecab()

def read_txt(file_name):
    data = []
    start = time.time()
    with open(f'./data/{file_name}', 'r') as file:
        while True:

            line = file.readline()
            line = re.sub("[ ]+" ," ", line)
            line = line.strip()
            if not line: 
                break

            words = mecab.morphs(line)
            words = [word for word in words if len(word) != 1]
            data += [words]

    end = time.time()
    print(f"{file_name} 걸린 시간 : {end - start}")
    return data

file_name = "synopsis_SF.txt"
data = read_txt(file_name)
# Out:
# synopsis_SF.txt 걸린 시간 : 0.3048737049102783

# %% [markdown]
# 장르별 텍스트 파일을 불러오면서 기본적인 전처리를 사용하였습니다.
# - 의미없이 반복되는 공백 제거
# - 문장 앞 뒤 공백 제거
# - 형태소 분석기 Mecab을 사용한 형태소 단위 분절
#     - 형태소 단위로 분절한 이유는 명사 단위로 분절한 경우 word2vec의 유사한 단어들이 관련성이 없는 단어들이 출현하는 문제를 해결하기 위함 입니다.
#     - 형태소 단위로 분절한 다음 글자의 길이가 1인 단어들은 제외하였습니다.

# %% [markdown]
# ## STEP 2. 추출된 명사로 Embedding model

# %%
# tokenized에 담긴 데이터를 가지고 나만의 Word2Vec을 생성합니다. (Gensim 4.0 기준)
model = Word2Vec(data, vector_size=100, window=5, min_count=3, sg=1)  
model.wv.most_similar(positive=['SF'])
# Out:
# [('기술', 0.9984247088432312),
#  ('소년', 0.9983887076377869),
#  ('흔적', 0.9983702898025513),
#  ('불명', 0.9983617067337036),
#  ('작전', 0.9983556270599365),
#  ('사이', 0.9983522295951843),
#  ('돌아온', 0.9983504414558411),
#  ('돌아가', 0.998339831829071),
#  ('실종', 0.9983293414115906),
#  ('이끄', 0.9983225464820862)]

# %% [markdown]
# ## STEP 3. target, attribute 단어 셋 만들기

# %%
genre_txt = ['synopsis_SF.txt', 'synopsis_family.txt', 'synopsis_show.txt', 'synopsis_horror.txt', 'synopsis_etc.txt', 
             'synopsis_documentary.txt', 'synopsis_drama.txt', 'synopsis_romance.txt', 'synopsis_musical.txt', 
             'synopsis_mystery.txt', 'synopsis_crime.txt', 'synopsis_historical.txt', 'synopsis_western.txt', 
             'synopsis_adult.txt', 'synopsis_thriller.txt', 'synopsis_animation.txt', 'synopsis_action.txt', 
             'synopsis_adventure.txt', 'synopsis_war.txt', 'synopsis_comedy.txt', 'synopsis_fantasy.txt']
genre_name = ['예술','일반','SF', '가족', '공연', '공포', '기타', '다큐멘터리', '드라마', '로맨스', '뮤지컬', '미스터리', '범죄', '역사', '서부극',
         '성인', '스릴러', '애니메이션', '액션', '모험', '전쟁', '코미디', '판타지']

# %%
data = []
for txt in genre_txt:
    data += read_txt(txt)
    
model = Word2Vec(data, vector_size=100, window=5, min_count=3, sg=1)
# Out:
# synopsis_SF.txt 걸린 시간 : 0.3081982135772705
# synopsis_family.txt 걸린 시간 : 0.11752080917358398
# synopsis_show.txt 걸린 시간 : 0.1070106029510498
# synopsis_horror.txt 걸린 시간 : 0.8529002666473389
# synopsis_etc.txt 걸린 시간 : 0.7093343734741211
# synopsis_documentary.txt 걸린 시간 : 2.244701862335205
# synopsis_drama.txt 걸린 시간 : 5.660510778427124
# synopsis_romance.txt 걸린 시간 : 1.4996099472045898
# synopsis_musical.txt 걸린 시간 : 0.047507524490356445
# synopsis_mystery.txt 걸린 시간 : 0.22993803024291992
# synopsis_crime.txt 걸린 시간 : 0.40747785568237305
# synopsis_historical.txt 걸린 시간 : 0.048900604248046875
# synopsis_western.txt 걸린 시간 : 0.013118267059326172
# synopsis_adult.txt 걸린 시간 : 0.6848807334899902
# synopsis_thriller.txt 걸린 시간 : 0.6202895641326904
# synopsis_animation.txt 걸린 시간 : 1.7716217041015625
# synopsis_action.txt 걸린 시간 : 1.6041827201843262
# synopsis_adventure.txt 걸린 시간 : 0.14031291007995605
# synopsis_war.txt 걸린 시간 : 0.11630702018737793
# synopsis_comedy.txt 걸린 시간 : 1.5651836395263672
# synopsis_fantasy.txt 걸린 시간 : 0.17719078063964844

# %% [markdown]
# ## STEP 4. 장르별 WEAT 계산하기

# %%
# 코사인 유사도
def cos_sim(i, j):
    return np.dot(i, j.T)/(np.linalg.norm(i)*np.linalg.norm(j))

# %% [markdown]
# WEAT 계산을 위해서 단어별 코사인 유사도를 구하는 함수를 만들어 줍니다.

# %%
def similar_word_arr(model, genre_name):
    similar_words = model.wv.most_similar(positive=[genre_name])
    similar_words = list(map(lambda x: x[0], similar_words))
    similar_arr = [model.wv[word] for word in similar_words]
    return similar_words, similar_arr


from collections import defaultdict
result = defaultdict()

for i in range(len(genre_name)):
    result[genre_name[i]] = similar_word_arr(model, genre_name[i])
result = dict(result)

# %% [markdown]
# 각 장르별로 유사한 단어 10개씩 뽑고 각 단어별 임베딩 벡터를 가져와서 dict타입으로 저장합니다.

# %%
# 하나의 타겟 단어와 여러개의 attribute 단어들
def s(w, a, b):
    similar_tar_attr_01 = []
    for attr in a:
        similar_tar_attr_01 += [cos_sim(w[1], attr[1])]

    mean_similar_01 = np.mean(similar_tar_attr_01)

    similar_tar_attr_02 = []
    for attr in b:
        similar_tar_attr_02 += [cos_sim(w[1], attr[1])]

    mean_similar_02 = np.mean(similar_tar_attr_02)
    
    return mean_similar_01 - mean_similar_02

# %% [markdown]
# 하나의 target 단어에 있는 target 단어와 유사한 단어 10개와 여러개의 attribute1 단어들의 10개의 평균 유사도와 attribute2 단어들의 10개의 평균 유사도를 계산하여 서로 빼줍니다.

# %%
def weat_score(w1, w2, a, b):
    mean_s_01 = []
    for w in w1:
        mean_s_01 += [s(w, a, b)]
    mean01 = np.mean(mean_s_01)
    
    mean_s_02 = []
    for w in w2:
        mean_s_02 += [s(w, a, b)]
    mean02 = np.mean(mean_s_02)
    
    std = np.std(np.concatenate([mean_s_01, mean_s_02]))
    
    return (mean01 - mean02) / std

# %% [markdown]
# target 단어1은 예술 장르와 유사한 단어 10개들이고 target 단어2는 일반 장르와 유사한 단어들 10개들을 사용하여 들어오는 attribute 장르들의 편향성을 계산하는 WEAT score를 구해줍니다.

# %%
target_word_01, target_arr_01 = result[genre_name[0]]
target_word_02, target_arr_02 = result[genre_name[1]]


art_bias = []
normal_bias = []
nothing_bias = []

for i in range(2, len(result)):
    attr_word_01, attr_arr_01 = result[genre_name[i]]
    for j in range(i + 1, len(result)):
        attr_word_02, attr_arr_02 = result[genre_name[j]]
        
        weat = weat_score(target_arr_01, target_arr_02, attr_arr_01, attr_arr_02)
        if weat > 0.05:
            print(f"\"{genre_name[0]}\"는 \"{genre_name[i]}\"에 편향되어 있습니다. {weat}")
            art_bias += [genre_name[i]]
            print(f"\"{genre_name[1]}\"는 \"{genre_name[j]}\"에 편향되어 있습니다. {weat}")
            normal_bias += [genre_name[j]]
        elif weat < -0.05:
            print(f"\"{genre_name[0]}\" 장르는 \"{genre_name[j]}\" 장르에 편향되어 있습니다. {weat}")
            art_bias += [genre_name[j]]
            print(f"\"{genre_name[1]}\" 장르는 \"{genre_name[i]}\" 장르에 편향되어 있습니다. {weat}")
            normal_bias += [genre_name[i]]
        elif weat >= -0.05 and weat <= 0.05:
            print(f"\"{genre_name[0]}\" 장르는 편향되지 않은 장르입니다. {weat}")        
            nothing_bias += [genre_name[j]]
# Out:
# "예술" 장르는 "가족" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "공연" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "공포" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "기타" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "로맨스" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401679396629333
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679396629333
# "예술" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401679396629333
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679396629333
# "예술" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "전쟁" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "SF" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "가족"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "기타"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "가족"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "다큐멘터리"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "가족"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in float_scalars
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "미스터리"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "모험"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "가족"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "가족"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "가족"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "판타지"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공연"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "기타"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공연"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "다큐멘터리"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공연"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "미스터리"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "모험"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공연"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공연"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공연"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "판타지"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공포"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "기타"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공포"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "다큐멘터리"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공포"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "미스터리"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "모험"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "공포"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "공포"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "공포"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "판타지"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "다큐멘터리"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "드라마"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "로맨스" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "기타" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술"는 "기타"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "기타"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "미스터리"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "기타" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "성인"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "액션"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "기타"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "로맨스" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "다큐멘터리"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "역사"에 편향되어 있습니다. 0.8401681780815125
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "다큐멘터리"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401681780815125
# "예술" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "다큐멘터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "로맨스" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "역사"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "액션"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "드라마"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "드라마" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "미스터리"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "모험"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "로맨스"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "판타지"에 편향되어 있습니다. 0.8401681780815125
# "예술" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "역사"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "뮤지컬"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "뮤지컬" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "역사"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "미스터리"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "미스터리" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "역사"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "액션"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "범죄"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "범죄" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "서부극" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "전쟁" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "역사" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "모험"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "서부극"에 편향되어 있습니다. 0.8401681780815125
# "일반"는 "판타지"에 편향되어 있습니다. 0.8401681780815125
# "예술"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "스릴러"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "성인"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "액션"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "성인"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술"는 "성인"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "성인" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "전쟁" 장르에 편향되어 있습니다. -0.8401681780815125
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401681780815125
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "스릴러" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술"는 "애니메이션"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "애니메이션" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "모험" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "액션"에 편향되어 있습니다. 0.8401680588722229
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401680588722229
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "액션" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술"는 "모험"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "전쟁"에 편향되어 있습니다. 0.8401679992675781
# "예술"는 "모험"에 편향되어 있습니다. 0.8401679992675781
# "일반"는 "코미디"에 편향되어 있습니다. 0.8401679992675781
# "예술" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401680588722229
# "일반" 장르는 "전쟁" 장르에 편향되어 있습니다. -0.8401680588722229
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "전쟁" 장르에 편향되어 있습니다. -0.8401679992675781
# "예술" 장르는 "판타지" 장르에 편향되어 있습니다. -0.8401679992675781
# "일반" 장르는 "코미디" 장르에 편향되어 있습니다. -0.8401679992675781

# %% [markdown]
# WEAT score를 계산하여 예술 분야에 편향된 장르들과 일반 분야에 편향된 장르들을 나누어서 서로 다른 list에 넣어주어 관리합니다.

# %%
len(genre_name)
# Out:
# 23

# %% [markdown]
# 사용된 장르의 총 개수는 23개로 target 장르로 사용된 예술과 일반을 제외하면 총 21개의 장르가 존재하게 됩니다.

# %%
# 예술 분야에 편향된 장르
set(art_bias) - set(normal_bias)
# Out:
# {'가족', '공연', '공포', '로맨스', '서부극'}

# %% [markdown]
# 앞서 예술 분야로 분리된 장르중에서 예술 분야에만 있는 장르들을 구하면 [가족, 공연, 공포, 로맨스, 서부극] 장르가 포함되어 있는 것을 알 수가 있었습니다.

# %%
# 일반 분야에 편향된 장르
set(normal_bias) - set(art_bias)
# Out:
# {'SF'}

# %% [markdown]
# 일반 분야에만 포함하고 있는 장르난 [SF] 하나의 장르만 존재합니다.

# %%
nothing_bias
# Out:
# []

# %% [markdown]
# 어떠한 분야에도 편향되지 않은 장르는 존재하지 않습니다.

# %% [markdown]
# 앞서 언급한 장르들 말고 나머지 장르들은 예술과 일반 분야에 동시에 편향된 장르들이라고 볼 수 있습니다.

# %% [markdown]
# ## STEP 5. 예술, 일반장르 편향성 및 시각화

# %%
np.random.seed(0)

# 한글 지원 폰트
sns.set(font='NanumGothic')

# 마이너스 부호 

plt.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt 
from matplotlib_venn import venn2, venn2_circles

plt.figure(figsize = (10, 10))
A = set(art_bias) 
B = set(normal_bias) 
v = venn2(subsets=[A, B], set_labels=('예술', '일반')) 
c = venn2_circles(subsets=[A, B], linestyle='solid')

v.get_label_by_id('100').set_text('\n'.join(map(str,A-B)))
v.get_label_by_id('110').set_text('\n'.join(map(str,A&B)))
v.get_label_by_id('010').set_text('\n'.join(map(str,B-A)))
